# %%
import math

class quadrado:

  def __init__(self, lado):

    if lado <=0 :
      raise ValueError("Lado deve ser positivo")
      def calcular_area(self):
        return self.lado ** 2
        def calcular_perimetro(self):
          return self.lado * 4
          def __str__(self):

            return f"objeto quadrado lado de : {self.lado}"
print(f"lado do quadrado:{a1.lado}")
print(f"area do quadrado: {q1.calcular_area()}")
print(f"perimetro do quadrado:{q1.calcular_perimetro()}")
print("imprimir o objetro")
print(q1)
print("-"* 20)
q2 = quadrado(12.5)
print()
print(q2)
print(f"area do segundo quadrado{q2.calcular_area()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1256431986.py in <cell line: 0>()
#      13
#      14             return f"objeto quadrado lado de : {self.lado}"
# ---> 15 print(f"lado do quadrado:{a1.lado}")
#      16 print(f"area do quadrado: {q1.calcular_area()}")
#      17 print(f"perimetro do quadrado:{q1.calcular_perimetro()}")
#
# NameError: name 'a1' is not defined

# %%
lista_string = input("insira uma lista de frutas separadas por virgula")
print(lista_string)
listanova = lista_string.split(",")
print(listanova)
lista2 = [frutas.strip() for frutas in listanova]
contagem = listanova.count(lista2)
print (f"{contagem}")
# Out:
# insira uma lista de frutas separadas por virgulaabc, oksda , asdaiosj, sasd
# abc, oksda , asdaiosj, sasd
# ['abc', ' oksda ', ' asdaiosj', ' sasd']
# 0

# %%
itens = input("insira")
lista_palavras = [x.strip() for x in itens]
palavra = input("digite a palavra que deseja encontrar")
quantidade = (pala)
# Out:
# insiraasdsadasdda
# digite a palavra que deseja encontrarsd
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3872259712.py in <cell line: 0>()
#       2 lista_palavras = [x.strip() for x in itens]
#       3 palavra = input("digite a palavra que deseja encontrar")
# ----> 4 quantidade = (pala)
#
# NameError: name 'pala' is not defined

# %%
lista_string = input("digite aqui a lista")
input = ("digite aqui")
lista =
novalista = list(set(lista))
print()
# Out:
# ['digite a entrada']

# %% [markdown]
# CONJUNTOS, LISTAS QUE NAO PERMITEM DADOS DUPLICADOS

# %%
lista_string = input("insira uma lista de frutas separadas por virgula")
print(lista_string)
listanova = lista_string.split(",")
print(listanova)
lista2 = [frutas.strip() for frutas in listanova]
contagem = listanova.count(lista2)

print (f"{contagem}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1139720377.py in <cell line: 0>()
# ----> 1 lista_string = input("insira uma lista de frutas separadas por virgula")
#       2 print(lista_string)
#       3 listanova = lista_string.split(",")
#       4 print(listanova)
#       5 lista2 = [frutas.strip() for frutas in listanova]
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# VARIAÇÕES DO FATIAMENTO

# %%
str = "programar"
slicing = str[0:4]
print(slicing)
# Out:
# prog

# %%
str = "escreva a palavra"
slicing = str[::-1]
print(slicing)
# Out:
# arvalap a avercse

# %%
str = "python programação"
slicing = str[10:6:-1]
print(slicing)
# Out:
# gorp

# %%
EXIBA EM LETRA MAIUSCULA

# %%
minha_string = "exiba em letra maiuscula"
string_maiuscula = minha_string.upper()
print(string_maiuscula)
print(minha_string)
# Out:
# EXIBA EM LETRA MAIUSCULA
# exiba em letra maiuscula

# %%
string = " programar é divertido"
substring = "fun"
index = string.find(substring)

if index != -1:
  print(f"A substring '{substring}' foi encontrada na posição: {index}")
else:
  print(f"A substring '{substring}' não foi encontrada.")
# Out:
# A substring 'fun' não foi encontrada.

# %%
texto = "manipulação"
p_4 = texto[:4]
print(p_4)
# Out:
# mani

# %% [markdown]
# exibir em ordem inversa

# %%
def inverter_string(texto):
  return texto[::-1]

  string_original = "olá mundo!"
  string_invertida = inverter_string(string_original)
  print(f"string original:{string_original}")
  print(f"string invertida:{string_invertida}")

# %%
def inverter_string(texto):
  return texto[::-1]

string_original = "PYTHON!"
string_invertida = inverter_string(string_original)
print(f"String original: {string_original}")
print(f"String invertida: {string_invertida}")
# Out:
# String original: PYTHON!
# String invertida: !NOHTYP

# %% [markdown]
# CONTAGEM QUANTAS VEZES A LETRA SE REPETE, EM COUNT

# %%
texto = "Esta é uma string. Esta string tem algumas palavras repetidas."
palavra = "string"
ocorrencias = texto.lower().split().count(palavra.lower())
print(f"A palavra '{palavra}' aparece {ocorrencias} vezes.")
# Out:
# A palavra 'string' aparece 1 vezes.

# %% [markdown]
# CONTAGEM QUANTAS VEZES A LETRA SE REPETE, EM COUNTER

# %%
from collections import Counter

texto = "programação é muito divertido"
palavras = texto.lower().split()
contagem = Counter(palavras)
palavra = ""
ocorrencias = contagem[palavra]
print(f"A palavra '{palavras}' aparece {ocorrencias} vezes.")
# Out:
# A palavra '['programação', 'é', 'muito', 'divertido']' aparece 0 vezes.

# %%
texto = "Programação é muito divertido"
sub_string = texto[-9:] # Últimos 9 caracteres
print(sub_string)
# Out:
# divertido
